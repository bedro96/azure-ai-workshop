# %% [markdown]
# ### 교육을 시작하기 앞서
#
# 1. Microsoft Foundry account 설정 및 project 생성
# 2. 필요한 기본 모델 배포.
# 3. SerpAPI에 대한 private key확보.
#
# 참고 문헌은 [foundry_setup.pdf](reference/foundry_setup.pdf) 참조해주시면 됩니다.
